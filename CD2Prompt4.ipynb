# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.poisson(5, 1000)
#print(x)

# %%
plt.hist(x, bins = 100, edgecolor ='black')
plt.xlabel('X')
plt.ylabel('Y')
plt.savefig("CD2Prompt34.png")
plt.show()
